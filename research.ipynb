# %% [markdown]
# ## Analysis of Accuracy and Loss Over Epochs in Different Learning Strategies
#
# ##### Overall setup: vocabulary_size = 3060, topics_size = 8

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##### RNN setup: dimension_hidden = 64, stops_coefficient = 0.25
# ##### Learning Strategy: 30 epochs with learning rate of 0.001, 5 epochs with learning rate of 0.005

# %%
epoch = range(35)
accuracy = [0.16957, 0.15563, 0.16609, 0.1928, 0.18235, 0.18583, 0.18467, 0.18467, 0.22648, 0.22532, 0.22648, 0.2288, 0.24623, 0.25436, 0.24158, 0.24506, 0.26597, 0.25784, 0.27294, 0.25319, 0.26132, 0.25668, 0.26132, 0.27178, 0.26481, 0.27294, 0.27178, 0.27991, 0.28455, 0.28107, 0.38908, 0.38908, 0.38328, 0.3705, 0.39837]
loss = [2.785, 2.597, 2.428, 2.327, 2.273, 2.28, 2.245, 2.18, 2.126, 2.075, 2.065, 2.056, 2.035, 2.013, 2.004, 1.999, 1.993, 1.986, 1.978, 1.979, 1.964, 1.962, 1.956, 1.957, 1.951, 1.948, 1.934, 1.94, 1.933, 1.943, 1.828, 1.834, 1.827, 1.831, 1.795]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(epoch, accuracy)
ax1.set_title('Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(top = 1, bottom = 0)

ax2.plot(epoch, loss)
ax2.set_title('Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim(top = 5, bottom = 0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### RNN setup: dimension_hidden = 128, stops_coefficient = 0.25
# ##### Learning Strategy: 30 epochs with learning rate of 0.001, 5 epochs with learning rate of 0.005

# %%
epoch = range(35)
accuracy = [0.13705, 0.13937, 0.15679, 0.13705, 0.14866, 0.15563, 0.16028, 0.15331, 0.16376, 0.17305, 0.18351, 0.17538, 0.19512, 0.19977, 0.19396, 0.18467, 0.18118, 0.21951, 0.2079, 0.20557, 0.22648, 0.22764, 0.20557, 0.21951, 0.23345, 0.2137, 0.23113, 0.223, 0.22416, 0.22648, 0.49129, 0.61092, 0.60046, 0.61556, 0.65738]
loss = [3.651, 3.258, 3.185, 3.148, 2.954, 2.855, 2.733, 2.744, 2.677, 2.583, 2.492, 2.468, 2.427, 2.357, 2.318, 2.361, 2.358, 2.286, 2.255, 2.278, 2.219, 2.241, 2.312, 2.211, 2.158, 2.153, 2.13, 2.152, 2.155, 2.162, 1.564, 1.205, 1.296, 1.189, 1.089]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(epoch, accuracy)
ax1.set_title('Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(top = 1, bottom = 0)

ax2.plot(epoch, loss)
ax2.set_title('Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim(top = 5, bottom = 0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### RNN setup: dimension_hidden = 256, stops_coefficient = 0.25
# ##### Learning Strategy: 30 epochs with learning rate of 0.001, 5 epochs with learning rate of 0.005

# %%
epoch = range(35)
accuracy = [0.12311, 0.13821, 0.13473, 0.13821, 0.15331, 0.14866, 0.15563, 0.18118, 0.18002, 0.18467, 0.17886, 0.19512, 0.19396, 0.21022, 0.18235, 0.19744, 0.20093, 0.20093, 0.21254, 0.20441, 0.21719, 0.22648, 0.22067, 0.26132, 0.30546, 0.29501, 0.34262, 0.38328, 0.39605, 0.37863, 0.64228, 0.69919, 0.69803, 0.73171, 0.69106]
loss = [5.143, 4.862, 4.559, 4.446, 3.987, 4.037, 3.831, 3.674, 3.529, 3.46, 3.519, 3.251, 3.16, 3.204, 3.122, 3.08, 3.026, 2.929, 2.856, 2.851, 2.748, 2.738, 2.706, 2.271, 2.224, 2.205, 2.055, 1.787, 1.818, 1.947, 1.168, 1.003, 1.007, 0.915, 1.049]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(epoch, accuracy)
ax1.set_title('Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(top = 1, bottom = 0)

ax2.plot(epoch, loss)
ax2.set_title('Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim(top = 5, bottom = 0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### RNN setup: dimension_hidden = [256 - blue, 128 - orange, 64 - green], stops_coefficient = 0.25
# ##### Learning Strategy: 30 epochs with learning rate of 0.001, 5 epochs with learning rate of 0.005

# %%
epoch = range(35)
accuracy_256 = [0.12311, 0.13821, 0.13473, 0.13821, 0.15331, 0.14866, 0.15563, 0.18118, 0.18002, 0.18467, 0.17886, 0.19512, 0.19396, 0.21022, 0.18235, 0.19744, 0.20093, 0.20093, 0.21254, 0.20441, 0.21719, 0.22648, 0.22067, 0.26132, 0.30546, 0.29501, 0.34262, 0.38328, 0.39605, 0.37863, 0.64228, 0.69919, 0.69803, 0.73171, 0.69106]
loss_256 = [5.143, 4.862, 4.559, 4.446, 3.987, 4.037, 3.831, 3.674, 3.529, 3.46, 3.519, 3.251, 3.16, 3.204, 3.122, 3.08, 3.026, 2.929, 2.856, 2.851, 2.748, 2.738, 2.706, 2.271, 2.224, 2.205, 2.055, 1.787, 1.818, 1.947, 1.168, 1.003, 1.007, 0.915, 1.049]
accuracy_128 = [0.13705, 0.13937, 0.15679, 0.13705, 0.14866, 0.15563, 0.16028, 0.15331, 0.16376, 0.17305, 0.18351, 0.17538, 0.19512, 0.19977, 0.19396, 0.18467, 0.18118, 0.21951, 0.2079, 0.20557, 0.22648, 0.22764, 0.20557, 0.21951, 0.23345, 0.2137, 0.23113, 0.223, 0.22416, 0.22648, 0.49129, 0.61092, 0.60046, 0.61556, 0.65738]
loss_128 = [3.651, 3.258, 3.185, 3.148, 2.954, 2.855, 2.733, 2.744, 2.677, 2.583, 2.492, 2.468, 2.427, 2.357, 2.318, 2.361, 2.358, 2.286, 2.255, 2.278, 2.219, 2.241, 2.312, 2.211, 2.158, 2.153, 2.13, 2.152, 2.155, 2.162, 1.564, 1.205, 1.296, 1.189, 1.089]
accuracy_64 = [0.16957, 0.15563, 0.16609, 0.1928, 0.18235, 0.18583, 0.18467, 0.18467, 0.22648, 0.22532, 0.22648, 0.2288, 0.24623, 0.25436, 0.24158, 0.24506, 0.26597, 0.25784, 0.27294, 0.25319, 0.26132, 0.25668, 0.26132, 0.27178, 0.26481, 0.27294, 0.27178, 0.27991, 0.28455, 0.28107, 0.38908, 0.38908, 0.38328, 0.3705, 0.39837]
loss_64 = [2.785, 2.597, 2.428, 2.327, 2.273, 2.28, 2.245, 2.18, 2.126, 2.075, 2.065, 2.056, 2.035, 2.013, 2.004, 1.999, 1.993, 1.986, 1.978, 1.979, 1.964, 1.962, 1.956, 1.957, 1.951, 1.948, 1.934, 1.94, 1.933, 1.943, 1.828, 1.834, 1.827, 1.831, 1.795]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(epoch, accuracy_256)
ax1.plot(epoch, accuracy_128)
ax1.plot(epoch, accuracy_64)
ax1.set_title('Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(top = 1, bottom = 0)

ax2.plot(epoch, loss_256)
ax2.plot(epoch, loss_128)
ax2.plot(epoch, loss_64)
ax2.set_title('Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim(top = 5, bottom = 0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### RNN setup: dimension_hidden = 64, stops_coefficient = 0.25
# ##### Learning Strategy: 10 epochs with learning rate of 0.01, 10 epochs with learning rate of 0.005, 10 epochs with learning rate of 0.001

# %%
epoch = range(30)
loss = [1.984, 1.446, 1.189, 1.296, 1.991, 1.112, 1.168, 1.077, 1.042, 1.025, 1.278, 1.25, 1.219, 1.208, 1.219, 1.201, 1.238, 1.225, 1.237, 1.233, 1.818, 1.769, 1.766, 1.857, 1.798, 1.748, 1.734, 1.741, 1.741, 1.743]
accuracy = [0.35424, 0.54704, 0.62369, 0.59233, 0.33914, 0.64925, 0.61556, 0.65738, 0.66551, 0.67944, 0.55981, 0.57724, 0.58769, 0.58304, 0.5842, 0.59698, 0.59233, 0.58653, 0.58188, 0.59001, 0.31707, 0.33217, 0.34379, 0.29501, 0.32869, 0.34727, 0.35192, 0.34843, 0.35308, 0.3554]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(epoch, accuracy)
ax1.set_title('Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(top = 1, bottom = 0)

ax2.plot(epoch, loss)
ax2.set_title('Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim(top = 5, bottom = 0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### RNN setup: dimension_hidden = 64, stops_coefficient = 0.25
# ##### Learning Strategy: 10 epochs with learning rate of 0.001, 10 epochs with learning rate of 0.005, 10 epochs with learning rate of 0.01

# %%
epoch = range(30)
loss = [2.971, 2.736, 2.633, 2.416, 2.323, 2.188, 2.163, 2.124, 2.134, 2.088, 1.978, 1.749, 1.616, 1.704, 1.701, 1.451, 1.458, 1.477, 1.407, 1.374, 2.971, 2.736, 2.633, 2.416, 2.323, 2.188, 2.163, 2.124, 2.134, 2.088]
accuracy = [0.14634, 0.14518, 0.13008, 0.14983, 0.16957, 0.18002, 0.19861, 0.19396, 0.19512, 0.21254, 0.29268, 0.36702, 0.42509, 0.39257, 0.41696, 0.4971, 0.49477, 0.48084, 0.50639, 0.53426, 0.14634, 0.14518, 0.13008, 0.14983, 0.16957, 0.18002, 0.19861, 0.19396, 0.19512, 0.21254]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(epoch, accuracy)
ax1.set_title('Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(top = 1, bottom = 0)

ax2.plot(epoch, loss)
ax2.set_title('Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim(top = 5, bottom = 0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### RNN setup: dimension_hidden = 64, stops_coefficient = 0.25
# ##### Learning Strategy: 10 epochs with learning rate of 0.01, 10 epochs with learning rate of 0.005, 10 epochs with learning rate of 0.001; and vice versa

# %%
epoch = range(30)
loss = [1.984, 1.446, 1.189, 1.296, 1.991, 1.112, 1.168, 1.077, 1.042, 1.025, 1.278, 1.25, 1.219, 1.208, 1.219, 1.201, 1.238, 1.225, 1.237, 1.233, 1.818, 1.769, 1.766, 1.857, 1.798, 1.748, 1.734, 1.741, 1.741, 1.743]
accuracy = [0.35424, 0.54704, 0.62369, 0.59233, 0.33914, 0.64925, 0.61556, 0.65738, 0.66551, 0.67944, 0.55981, 0.57724, 0.58769, 0.58304, 0.5842, 0.59698, 0.59233, 0.58653, 0.58188, 0.59001, 0.31707, 0.33217, 0.34379, 0.29501, 0.32869, 0.34727, 0.35192, 0.34843, 0.35308, 0.3554]
loss_ = [2.971, 2.736, 2.633, 2.416, 2.323, 2.188, 2.163, 2.124, 2.134, 2.088, 1.978, 1.749, 1.616, 1.704, 1.701, 1.451, 1.458, 1.477, 1.407, 1.374, 2.971, 2.736, 2.633, 2.416, 2.323, 2.188, 2.163, 2.124, 2.134, 2.088]
accuracy_ = [0.14634, 0.14518, 0.13008, 0.14983, 0.16957, 0.18002, 0.19861, 0.19396, 0.19512, 0.21254, 0.29268, 0.36702, 0.42509, 0.39257, 0.41696, 0.4971, 0.49477, 0.48084, 0.50639, 0.53426, 0.14634, 0.14518, 0.13008, 0.14983, 0.16957, 0.18002, 0.19861, 0.19396, 0.19512, 0.21254]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(epoch, accuracy)
ax1.plot(epoch, accuracy_)
ax1.set_title('Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.set_ylim(top = 1, bottom = 0)

ax2.plot(epoch, loss)
ax2.plot(epoch, loss_)
ax2.set_title('Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.set_ylim(top = 5, bottom = 0)

plt.tight_layout()
plt.show()
